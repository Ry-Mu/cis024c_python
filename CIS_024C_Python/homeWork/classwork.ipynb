# %%
# %%writefile main.py

def add(n1,n2):
    return n1 + n2

print add(1,2)
# Out:
# Overwriting main.py

# %%
# !python main.py
# Out:
# 3

# %%
# %%writefile getage.py

userAge = int(raw_input("Enter your age: "))

print userAge
# Out:
# Overwriting getage.py

# %%
# !python getage.py
# Out:
# Enter your age:
