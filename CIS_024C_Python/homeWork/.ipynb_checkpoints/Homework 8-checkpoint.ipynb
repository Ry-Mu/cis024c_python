# %%
"""
Exercise 1 - Testing your knowledge of External Libraries
Answer the below questions:
1. Name two benefits of using external libraries.
2. What are the different ways of including an external library 
in a Python program?
"""

# %%
"""
Exercise 2 - Using the math library
Import the math library in your program and do the following:

1. Request the user to enter a number between 1 and 10
2. Compute the log (math.log) of the number
3. Compute teh factorial (math.factorial) of the number
4. Compute the square root (math.sqrt) of the number
5. Compute the sine (math.sin) of the number
"""
import math

#Problem 1
userNum = int(raw_input("Please a number between 1-10: "))

#problem 2
log = math.log(userNum)
print "The log of your number is:",log

#problem 3
factorial = math.factorial(userNum)
print "The factorial of your number is:",factorial

#problem 4
sqRoot = math.sqrt(userNum)
print "The square root of your number is:",sqRoot

#problem 5
sine = math.sin(userNum)
print "The sine of your number is:",sine
# Out:
# Please a number between 1-10: 9
# The log of your number is: 2.19722457734
# The factorial of your number is: 362880
# The square root of your number is: 3.0
# The sine of your number is: 0.412118485242

# %%
"""
Exercise 3 - Random numbers
Generate a list of 10 random numbers between 1 and 100. 
Use random.sample function. 

Write a program to then sort the 
list of numbers in ascending order.
"""
import random

sampleOne = random.sample(range(100),10)
sampleTwo = random.sample(range(100),10)

print "Sameple 1: ",sampleOne
print "Sameple 2: ",sampleTwo

print "Sample 1 in ascending order: ", sorted(sampleOne)
# Out:
# Sameple 1:  [32, 25, 26, 60, 61, 92, 98, 49, 68, 75]
# Sameple 2:  [91, 39, 73, 0, 89, 45, 49, 15, 20, 7]
# Sample 1 in ascending order:  [25, 26, 32, 49, 60, 61, 68, 75, 92, 98]

# %%
"""
Exercise 4 - Creating your own library
Create a python module helperfunctions.py with the following functions:

1. add - returns the sum of two numbers
2. diff - returns the difference between two numbers
3. product - returns the product of two numbers
4. greatest - returns the greatest of two numbers.

Import this module in your python program and use the functions you 
created on any two numbers and print the result.

Note: Upload the helperfunctions.py module to your github folder 
along with the notebook file. You can also upload helperfunctions.py to 
Canvas if you are having trouble copying it to Github
"""

from helperFunctions import add
print add(2,3),diff(2,3),product(2,3),greatest(2,3)

print "1. Using the add function: add(2,3) = ",add(2,3)

print "2. Using the diff function: diff(2,3) = ",diff(2,3)

print "3. Using the product function: product(2,3) = ",product(2,3)

print "4. Using the greatest function: greatest(2,3) = ",greatest(2,3)
# Out:
# 5 5 5 3
# 1. Using the add function: add(2,3) =  5
# 2. Using the diff function: diff(2,3) =  5
# 3. Using the product function: product(2,3) =  5
# 4. Using the greatest function: greatest(2,3) =  3

# %%
"""
Exercise 5 - Compressing a file using the zlib library
Download the story Alice in Wonderland from the link below:
http://www.gutenberg.org/files/11/11.txt and save it as the 
file alice.txt

Write a python program to open this file in your program. 
Use the zlib library to compress the contents of the file and 
write it back to another file call alice_compressed.txt

Now, open the file alice_compressed.txt, decompress using the zlib 
library and display the results on the screen.

Refer to Week 8 lecture slides and classwork for information on
how to use zlib.
"""

readFile = open("alice.txt")
readFile.readlines()
# Out:
# ['\xef\xbb\xbfProject Gutenberg\xe2\x80\x99s Alice\xe2\x80\x99s Adventures in Wonderland, by Lewis Carroll\r\n',
#  '\r\n',
#  'This eBook is for the use of anyone anywhere at no cost and with\r\n',
#  'almost no restrictions whatsoever.  You may copy it, give it away or\r\n',
#  're-use it under the terms of the Project Gutenberg License included\r\n',
#  'with this eBook or online at www.gutenberg.org\r\n',
#  '\r\n',
#  '\r\n',
#  'Title: Alice\xe2\x80\x99s Adventures in Wonderland\r\n',
#  '\r\n',
#  'Author: Lewis Carroll\r\n',
#  '\r\n',
#  'Posting Date: June 25, 2008 [EBook #11]\r\n',
#  'Release Date: March, 1994\r\n',
#  'Last Updated: October 6, 2016\r\n',
#  '\r\n',
#  'Language: English\r\n',
#  '\r\n',
#  'Character set encoding: UTF-8\r\n',
#  '\r\n',
#  '*** START OF THIS PROJECT GUTENBERG EBOOK ALICE\xe2\x80\x99S ADVENTURES IN WONDERLAND ***\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  'ALICE\xe2\x80\x99S ADVENTURES IN WONDERLAND\r\n',
#  '\r\n',
#  'Lewis Carroll\r\n',
#  '\r\n',
#  'THE MILLENNIUM FULCRUM EDITION 3.0\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  'CHAPTER I. Down the Rabbit-Hole\r\n',
#  '\r\n',
#  'Alice was beginning to get very tired of sitting by her sister on the\r\n',
#  'bank, and of having nothing to do: once or twice she had peeped into the\r\n',
#  'book her sister was reading, but it had no pictures or conversations in\r\n',
#  'it, \xe2\x80\x98and what is the use of a book,\xe2\x80\x99 thought Alice \xe2\x80\x98without pictures or\r\n',
#  'conversations?\xe2\x80\x99\r\n',
#  '\r\n',
#  'So she was considering in her own mind (as well as she could, for the\r\n',
#  'hot day made her feel very sleepy and stupid), whether the pleasure\r\n',
#  'of making a daisy-chain would be worth the trouble of getting up and\r\n',
#  'picking the daisies, when suddenly a White Rabbit with pink eyes ran\r\n',
#  'close by her.\r\n',
#  '\r\n',
#  'There was nothing so VERY remarkable in that; nor did Alice think it so\r\n',
#  'VERY much out of the way to hear the Rabbit say to itself, \xe2\x80\x98Oh dear!\r\n',
#  'Oh dear! I shall be late!\xe2\x80\x99 (when she thought it over afterwards, it\r\n',
#  'occurred to her that she ought to have wondered at this, but at the time\r\n',
#  'it all seemed quite natural); but when the Rabbit actually TOOK A WATCH\r\n',
#  'OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,\r\n',
#  'Alice started to her feet, for it flashed across her mind that she had\r\n',
#  'never before seen a rabbit with either a waistcoat-pocket, or a watch\r\n',
#  'to take out of it, and burning with curiosity, she ran across the field\r\n',
#  'after it, and fortunately was just in time to see it pop down a large\r\n',
#  'rabbit-hole under the hedge.\r\n',
#  '\r\n',
#  'In another moment down went Alice after it, never once considering how\r\n',
#  'in the world she was to get out again.\r\n',
#  '\r\n',
#  'The rabbit-hole went straight on like a tunnel for some way, and then\r\n',
#  'dipped suddenly down, so suddenly that Alice had not a moment to think\r\n',
#  'about stopping herself before she found herself falling down a very deep\r\n',
#  'well.\r\n',
#  '\r\n',
#  'Either the well was very deep, or she fell very slowly, for she had\r\n',
#  'plenty of time as she went down to look about her and to wonder what was\r\n',
#  'going to happen next. First, she tried to look down and make out what\r\n',
#  'she was coming to, but it was too dark to see anything; then she\r\n',
#  'looked at the sides of the well, and noticed that they were filled with\r\n',
#  'cupboards and book-shelves; here and there she saw maps and pictures\r\n',
#  'hung upon pegs. She took down a jar from one of the shelves as\r\n',
#  'she passed; it was labelled \xe2\x80\x98ORANGE MARMALADE\xe2\x80\x99, but to her great\r\n',
#  'disappointment it was empty: she did not like to drop the jar for fear\r\n',
#  'of killing somebody, so managed to put it into one of the cupboards as\r\n',
#  'she fell past it.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Well!\xe2\x80\x99 thought Alice to herself, \xe2\x80\x98after such a fall as this, I shall\r\n',
#  'think nothing of tumbling down stairs! How brave they\xe2\x80\x99ll all think me at\r\n',
#  'home! Why, I wouldn\xe2\x80\x99t say anything about it, even if I fell off the top\r\n',
#  'of the house!\xe2\x80\x99 (Which was very likely true.)\r\n',
#  '\r\n',
#  'Down, down, down. Would the fall NEVER come to an end! \xe2\x80\x98I wonder how\r\n',
#  'many miles I\xe2\x80\x99ve fallen by this time?\xe2\x80\x99 she said aloud. \xe2\x80\x98I must be getting\r\n',
#  'somewhere near the centre of the earth. Let me see: that would be four\r\n',
#  'thousand miles down, I think--\xe2\x80\x99 (for, you see, Alice had learnt several\r\n',
#  'things of this sort in her lessons in the schoolroom, and though this\r\n',
#  'was not a VERY good opportunity for showing off her knowledge, as there\r\n',
#  'was no one to listen to her, still it was good practice to say it over)\r\n',
#  '\xe2\x80\x98--yes, that\xe2\x80\x99s about the right distance--but then I wonder what Latitude\r\n',
#  'or Longitude I\xe2\x80\x99ve got to?\xe2\x80\x99 (Alice had no idea what Latitude was, or\r\n',
#  'Longitude either, but thought they were nice grand words to say.)\r\n',
#  '\r\n',
#  'Presently she began again. \xe2\x80\x98I wonder if I shall fall right THROUGH the\r\n',
#  'earth! How funny it\xe2\x80\x99ll seem to come out among the people that walk with\r\n',
#  'their heads downward! The Antipathies, I think--\xe2\x80\x99 (she was rather glad\r\n',
#  'there WAS no one listening, this time, as it didn\xe2\x80\x99t sound at all the\r\n',
#  'right word) \xe2\x80\x98--but I shall have to ask them what the name of the country\r\n',
#  'is, you know. Please, Ma\xe2\x80\x99am, is this New Zealand or Australia?\xe2\x80\x99 (and\r\n',
#  'she tried to curtsey as she spoke--fancy CURTSEYING as you\xe2\x80\x99re falling\r\n',
#  'through the air! Do you think you could manage it?) \xe2\x80\x98And what an\r\n',
#  'ignorant little girl she\xe2\x80\x99ll think me for asking! No, it\xe2\x80\x99ll never do to\r\n',
#  'ask: perhaps I shall see it written up somewhere.\xe2\x80\x99\r\n',
#  '\r\n',
#  'Down, down, down. There was nothing else to do, so Alice soon began\r\n',
#  'talking again. \xe2\x80\x98Dinah\xe2\x80\x99ll miss me very much to-night, I should think!\xe2\x80\x99\r\n',
#  '(Dinah was the cat.) \xe2\x80\x98I hope they\xe2\x80\x99ll remember her saucer of milk at\r\n',
#  'tea-time. Dinah my dear! I wish you were down here with me! There are no\r\n',
#  'mice in the air, I\xe2\x80\x99m afraid, but you might catch a bat, and that\xe2\x80\x99s very\r\n',
#  'like a mouse, you know. But do cats eat bats, I wonder?\xe2\x80\x99 And here Alice\r\n',
#  'began to get rather sleepy, and went on saying to herself, in a dreamy\r\n',
#  'sort of way, \xe2\x80\x98Do cats eat bats? Do cats eat bats?\xe2\x80\x99 and sometimes, \xe2\x80\x98Do\r\n',
#  'bats eat cats?\xe2\x80\x99 for, you see, as she couldn\xe2\x80\x99t answer either question,\r\n',
#  'it didn\xe2\x80\x99t much matter which way she put it. She felt that she was dozing\r\n',
#  'off, and had just begun to dream that she was walking hand in hand with\r\n',
#  'Dinah, and saying to her very earnestly, \xe2\x80\x98Now, Dinah, tell me the truth:\r\n',
#  'did you ever eat a bat?\xe2\x80\x99 when suddenly, thump! thump! down she came upon\r\n',
#  'a heap of sticks and dry leaves, and the fall was over.\r\n',
#  '\r\n',
#  'Alice was not a bit hurt, and she jumped up on to her feet in a moment:\r\n',
#  'she looked up, but it was all dark overhead; before her was another\r\n',
#  'long passage, and the White Rabbit was still in sight, hurrying down it.\r\n',
#  'There was not a moment to be lost: away went Alice like the wind, and\r\n',
#  'was just in time to hear it say, as it turned a corner, \xe2\x80\x98Oh my ears\r\n',
#  'and whiskers, how late it\xe2\x80\x99s getting!\xe2\x80\x99 She was close behind it when she\r\n',
#  'turned the corner, but the Rabbit was no longer to be seen: she found\r\n',
#  'herself in a long, low hall, which was lit up by a row of lamps hanging\r\n',
#  'from the roof.\r\n',
#  '\r\n',
#  'There were doors all round the hall, but they were all locked; and when\r\n',
#  'Alice had been all the way down one side and up the other, trying every\r\n',
#  'door, she walked sadly down the middle, wondering how she was ever to\r\n',
#  'get out again.\r\n',
#  '\r\n',
#  'Suddenly she came upon a little three-legged table, all made of solid\r\n',
#  'glass; there was nothing on it except a tiny golden key, and Alice\xe2\x80\x99s\r\n',
#  'first thought was that it might belong to one of the doors of the hall;\r\n',
#  'but, alas! either the locks were too large, or the key was too small,\r\n',
#  'but at any rate it would not open any of them. However, on the second\r\n',
#  'time round, she came upon a low curtain she had not noticed before, and\r\n',
#  'behind it was a little door about fifteen inches high: she tried the\r\n',
#  'little golden key in the lock, and to her great delight it fitted!\r\n',
#  '\r\n',
#  'Alice opened the door and found that it led into a small passage, not\r\n',
#  'much larger than a rat-hole: she knelt down and looked along the passage\r\n',
#  'into the loveliest garden you ever saw. How she longed to get out of\r\n',
#  'that dark hall, and wander about among those beds of bright flowers and\r\n',
#  'those cool fountains, but she could not even get her head through the\r\n',
#  'doorway; \xe2\x80\x98and even if my head would go through,\xe2\x80\x99 thought poor Alice, \xe2\x80\x98it\r\n',
#  'would be of very little use without my shoulders. Oh, how I wish I could\r\n',
#  'shut up like a telescope! I think I could, if I only knew how to begin.\xe2\x80\x99\r\n',
#  'For, you see, so many out-of-the-way things had happened lately,\r\n',
#  'that Alice had begun to think that very few things indeed were really\r\n',
#  'impossible.\r\n',
#  '\r\n',
#  'There seemed to be no use in waiting by the little door, so she went\r\n',
#  'back to the table, half hoping she might find another key on it, or at\r\n',
#  'any rate a book of rules for shutting people up like telescopes: this\r\n',
#  'time she found a little bottle on it, [\xe2\x80\x98which certainly was not here\r\n',
#  'before,\xe2\x80\x99 said Alice,) and round the neck of the bottle was a paper\r\n',
#  'label, with the words \xe2\x80\x98DRINK ME\xe2\x80\x99 beautifully printed on it in large\r\n',
#  'letters.\r\n',
#  '\r\n',
#  'It was all very well to say \xe2\x80\x98Drink me,\xe2\x80\x99 but the wise little Alice was\r\n',
#  'not going to do THAT in a hurry. \xe2\x80\x98No, I\xe2\x80\x99ll look first,\xe2\x80\x99 she said, \xe2\x80\x98and\r\n',
#  'see whether it\xe2\x80\x99s marked \xe2\x80\x9cpoison\xe2\x80\x9d or not\xe2\x80\x99; for she had read several nice\r\n',
#  'little histories about children who had got burnt, and eaten up by wild\r\n',
#  'beasts and other unpleasant things, all because they WOULD not remember\r\n',
#  'the simple rules their friends had taught them: such as, that a red-hot\r\n',
#  'poker will burn you if you hold it too long; and that if you cut your\r\n',
#  'finger VERY deeply with a knife, it usually bleeds; and she had never\r\n',
#  'forgotten that, if you drink much from a bottle marked \xe2\x80\x98poison,\xe2\x80\x99 it is\r\n',
#  'almost certain to disagree with you, sooner or later.\r\n',
#  '\r\n',
#  'However, this bottle was NOT marked \xe2\x80\x98poison,\xe2\x80\x99 so Alice ventured to taste\r\n',
#  'it, and finding it very nice, (it had, in fact, a sort of mixed flavour\r\n',
#  'of cherry-tart, custard, pine-apple, roast turkey, toffee, and hot\r\n',
#  'buttered toast,) she very soon finished it off.\r\n',
#  '\r\n',
#  '  *    *    *    *    *    *    *\r\n',
#  '\r\n',
#  '    *    *    *    *    *    *\r\n',
#  '\r\n',
#  '  *    *    *    *    *    *    *\r\n',
#  '\r\n',
#  '\xe2\x80\x98What a curious feeling!\xe2\x80\x99 said Alice; \xe2\x80\x98I must be shutting up like a\r\n',
#  'telescope.\xe2\x80\x99\r\n',
#  '\r\n',
#  'And so it was indeed: she was now only ten inches high, and her face\r\n',
#  'brightened up at the thought that she was now the right size for going\r\n',
#  'through the little door into that lovely garden. First, however, she\r\n',
#  'waited for a few minutes to see if she was going to shrink any further:\r\n',
#  'she felt a little nervous about this; \xe2\x80\x98for it might end, you know,\xe2\x80\x99 said\r\n',
#  'Alice to herself, \xe2\x80\x98in my going out altogether, like a candle. I wonder\r\n',
#  'what I should be like then?\xe2\x80\x99 And she tried to fancy what the flame of a\r\n',
#  'candle is like after the candle is blown out, for she could not remember\r\n',
#  'ever having seen such a thing.\r\n',
#  '\r\n',
#  'After a while, finding that nothing more happened, she decided on going\r\n',
#  'into the garden at once; but, alas for poor Alice! when she got to the\r\n',
#  'door, she found she had forgotten the little golden key, and when she\r\n',
#  'went back to the table for it, she found she could not possibly reach\r\n',
#  'it: she could see it quite plainly through the glass, and she tried her\r\n',
#  'best to climb up one of the legs of the table, but it was too slippery;\r\n',
#  'and when she had tired herself out with trying, the poor little thing\r\n',
#  'sat down and cried.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Come, there\xe2\x80\x99s no use in crying like that!\xe2\x80\x99 said Alice to herself,\r\n',
#  'rather sharply; \xe2\x80\x98I advise you to leave off this minute!\xe2\x80\x99 She generally\r\n',
#  'gave herself very good advice, (though she very seldom followed it),\r\n',
#  'and sometimes she scolded herself so severely as to bring tears into\r\n',
#  'her eyes; and once she remembered trying to box her own ears for having\r\n',
#  'cheated herself in a game of croquet she was playing against herself,\r\n',
#  'for this curious child was very fond of pretending to be two people.\r\n',
#  '\xe2\x80\x98But it\xe2\x80\x99s no use now,\xe2\x80\x99 thought poor Alice, \xe2\x80\x98to pretend to be two people!\r\n',
#  'Why, there\xe2\x80\x99s hardly enough of me left to make ONE respectable person!\xe2\x80\x99\r\n',
#  '\r\n',
#  'Soon her eye fell on a little glass box that was lying under the table:\r\n',
#  'she opened it, and found in it a very small cake, on which the words\r\n',
#  '\xe2\x80\x98EAT ME\xe2\x80\x99 were beautifully marked in currants. \xe2\x80\x98Well, I\xe2\x80\x99ll eat it,\xe2\x80\x99 said\r\n',
#  'Alice, \xe2\x80\x98and if it makes me grow larger, I can reach the key; and if it\r\n',
#  'makes me grow smaller, I can creep under the door; so either way I\xe2\x80\x99ll\r\n',
#  'get into the garden, and I don\xe2\x80\x99t care which happens!\xe2\x80\x99\r\n',
#  '\r\n',
#  'She ate a little bit, and said anxiously to herself, \xe2\x80\x98Which way? Which\r\n',
#  'way?\xe2\x80\x99, holding her hand on the top of her head to feel which way it was\r\n',
#  'growing, and she was quite surprised to find that she remained the same\r\n',
#  'size: to be sure, this generally happens when one eats cake, but Alice\r\n',
#  'had got so much into the way of expecting nothing but out-of-the-way\r\n',
#  'things to happen, that it seemed quite dull and stupid for life to go on\r\n',
#  'in the common way.\r\n',
#  '\r\n',
#  'So she set to work, and very soon finished off the cake.\r\n',
#  '\r\n',
#  '  *    *    *    *    *    *    *\r\n',
#  '\r\n',
#  '    *    *    *    *    *    *\r\n',
#  '\r\n',
#  '  *    *    *    *    *    *    *\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  'CHAPTER II. The Pool of Tears\r\n',
#  '\r\n',
#  '\xe2\x80\x98Curiouser and curiouser!\xe2\x80\x99 cried Alice (she was so much surprised, that\r\n',
#  'for the moment she quite forgot how to speak good English); \xe2\x80\x98now I\xe2\x80\x99m\r\n',
#  'opening out like the largest telescope that ever was! Good-bye, feet!\xe2\x80\x99\r\n',
#  '(for when she looked down at her feet, they seemed to be almost out of\r\n',
#  'sight, they were getting so far off). \xe2\x80\x98Oh, my poor little feet, I wonder\r\n',
#  'who will put on your shoes and stockings for you now, dears? I\xe2\x80\x99m sure\r\n',
#  '_I_ shan\xe2\x80\x99t be able! I shall be a great deal too far off to trouble\r\n',
#  'myself about you: you must manage the best way you can;--but I must be\r\n',
#  'kind to them,\xe2\x80\x99 thought Alice, \xe2\x80\x98or perhaps they won\xe2\x80\x99t walk the way I want\r\n',
#  'to go! Let me see: I\xe2\x80\x99ll give them a new pair of boots every Christmas.\xe2\x80\x99\r\n',
#  '\r\n',
#  'And she went on planning to herself how she would manage it. \xe2\x80\x98They must\r\n',
#  'go by the carrier,\xe2\x80\x99 she thought; \xe2\x80\x98and how funny it\xe2\x80\x99ll seem, sending\r\n',
#  'presents to one\xe2\x80\x99s own feet! And how odd the directions will look!\r\n',
#  '\r\n',
#  '     ALICE\xe2\x80\x99S RIGHT FOOT, ESQ.\r\n',
#  '       HEARTHRUG,\r\n',
#  '         NEAR THE FENDER,\r\n',
#  '           (WITH ALICE\xe2\x80\x99S LOVE).\r\n',
#  '\r\n',
#  'Oh dear, what nonsense I\xe2\x80\x99m talking!\xe2\x80\x99\r\n',
#  '\r\n',
#  'Just then her head struck against the roof of the hall: in fact she was\r\n',
#  'now more than nine feet high, and she at once took up the little golden\r\n',
#  'key and hurried off to the garden door.\r\n',
#  '\r\n',
#  'Poor Alice! It was as much as she could do, lying down on one side, to\r\n',
#  'look through into the garden with one eye; but to get through was more\r\n',
#  'hopeless than ever: she sat down and began to cry again.\r\n',
#  '\r\n',
#  '\xe2\x80\x98You ought to be ashamed of yourself,\xe2\x80\x99 said Alice, \xe2\x80\x98a great girl like\r\n',
#  'you,\xe2\x80\x99 (she might well say this), \xe2\x80\x98to go on crying in this way! Stop this\r\n',
#  'moment, I tell you!\xe2\x80\x99 But she went on all the same, shedding gallons of\r\n',
#  'tears, until there was a large pool all round her, about four inches\r\n',
#  'deep and reaching half down the hall.\r\n',
#  '\r\n',
#  'After a time she heard a little pattering of feet in the distance, and\r\n',
#  'she hastily dried her eyes to see what was coming. It was the White\r\n',
#  'Rabbit returning, splendidly dressed, with a pair of white kid gloves in\r\n',
#  'one hand and a large fan in the other: he came trotting along in a great\r\n',
#  'hurry, muttering to himself as he came, \xe2\x80\x98Oh! the Duchess, the Duchess!\r\n',
#  'Oh! won\xe2\x80\x99t she be savage if I\xe2\x80\x99ve kept her waiting!\xe2\x80\x99 Alice felt so\r\n',
#  'desperate that she was ready to ask help of any one; so, when the Rabbit\r\n',
#  'came near her, she began, in a low, timid voice, \xe2\x80\x98If you please, sir--\xe2\x80\x99\r\n',
#  'The Rabbit started violently, dropped the white kid gloves and the fan,\r\n',
#  'and skurried away into the darkness as hard as he could go.\r\n',
#  '\r\n',
#  'Alice took up the fan and gloves, and, as the hall was very hot, she\r\n',
#  'kept fanning herself all the time she went on talking: \xe2\x80\x98Dear, dear! How\r\n',
#  'queer everything is to-day! And yesterday things went on just as usual.\r\n',
#  'I wonder if I\xe2\x80\x99ve been changed in the night? Let me think: was I the\r\n',
#  'same when I got up this morning? I almost think I can remember feeling a\r\n',
#  'little different. But if I\xe2\x80\x99m not the same, the next question is, Who\r\n',
#  'in the world am I? Ah, THAT\xe2\x80\x99S the great puzzle!\xe2\x80\x99 And she began thinking\r\n',
#  'over all the children she knew that were of the same age as herself, to\r\n',
#  'see if she could have been changed for any of them.\r\n',
#  '\r\n',
#  '\xe2\x80\x98I\xe2\x80\x99m sure I\xe2\x80\x99m not Ada,\xe2\x80\x99 she said, \xe2\x80\x98for her hair goes in such long\r\n',
#  'ringlets, and mine doesn\xe2\x80\x99t go in ringlets at all; and I\xe2\x80\x99m sure I can\xe2\x80\x99t\r\n',
#  'be Mabel, for I know all sorts of things, and she, oh! she knows such a\r\n',
#  'very little! Besides, SHE\xe2\x80\x99S she, and I\xe2\x80\x99m I, and--oh dear, how puzzling\r\n',
#  'it all is! I\xe2\x80\x99ll try if I know all the things I used to know. Let me\r\n',
#  'see: four times five is twelve, and four times six is thirteen, and\r\n',
#  'four times seven is--oh dear! I shall never get to twenty at that rate!\r\n',
#  'However, the Multiplication Table doesn\xe2\x80\x99t signify: let\xe2\x80\x99s try Geography.\r\n',
#  'London is the capital of Paris, and Paris is the capital of Rome, and\r\n',
#  'Rome--no, THAT\xe2\x80\x99S all wrong, I\xe2\x80\x99m certain! I must have been changed for\r\n',
#  'Mabel! I\xe2\x80\x99ll try and say \xe2\x80\x9cHow doth the little--\xe2\x80\x9c\xe2\x80\x99 and she crossed her\r\n',
#  'hands on her lap as if she were saying lessons, and began to repeat it,\r\n',
#  'but her voice sounded hoarse and strange, and the words did not come the\r\n',
#  'same as they used to do:--\r\n',
#  '\r\n',
#  '     \xe2\x80\x98How doth the little crocodile\r\n',
#  '      Improve his shining tail,\r\n',
#  '     And pour the waters of the Nile\r\n',
#  '      On every golden scale!\r\n',
#  '\r\n',
#  '     \xe2\x80\x98How cheerfully he seems to grin,\r\n',
#  '      How neatly spread his claws,\r\n',
#  '     And welcome little fishes in\r\n',
#  '      With gently smiling jaws!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I\xe2\x80\x99m sure those are not the right words,\xe2\x80\x99 said poor Alice, and her eyes\r\n',
#  'filled with tears again as she went on, \xe2\x80\x98I must be Mabel after all, and\r\n',
#  'I shall have to go and live in that poky little house, and have next to\r\n',
#  'no toys to play with, and oh! ever so many lessons to learn! No, I\xe2\x80\x99ve\r\n',
#  'made up my mind about it; if I\xe2\x80\x99m Mabel, I\xe2\x80\x99ll stay down here! It\xe2\x80\x99ll be no\r\n',
#  'use their putting their heads down and saying \xe2\x80\x9cCome up again, dear!\xe2\x80\x9d I\r\n',
#  'shall only look up and say \xe2\x80\x9cWho am I then? Tell me that first, and then,\r\n',
#  'if I like being that person, I\xe2\x80\x99ll come up: if not, I\xe2\x80\x99ll stay down here\r\n',
#  'till I\xe2\x80\x99m somebody else\xe2\x80\x9d--but, oh dear!\xe2\x80\x99 cried Alice, with a sudden burst\r\n',
#  'of tears, \xe2\x80\x98I do wish they WOULD put their heads down! I am so VERY tired\r\n',
#  'of being all alone here!\xe2\x80\x99\r\n',
#  '\r\n',
#  'As she said this she looked down at her hands, and was surprised to see\r\n',
#  'that she had put on one of the Rabbit\xe2\x80\x99s little white kid gloves while\r\n',
#  'she was talking. \xe2\x80\x98How CAN I have done that?\xe2\x80\x99 she thought. \xe2\x80\x98I must\r\n',
#  'be growing small again.\xe2\x80\x99 She got up and went to the table to measure\r\n',
#  'herself by it, and found that, as nearly as she could guess, she was now\r\n',
#  'about two feet high, and was going on shrinking rapidly: she soon found\r\n',
#  'out that the cause of this was the fan she was holding, and she dropped\r\n',
#  'it hastily, just in time to avoid shrinking away altogether.\r\n',
#  '\r\n',
#  '\xe2\x80\x98That WAS a narrow escape!\xe2\x80\x99 said Alice, a good deal frightened at the\r\n',
#  'sudden change, but very glad to find herself still in existence; \xe2\x80\x98and\r\n',
#  'now for the garden!\xe2\x80\x99 and she ran with all speed back to the little door:\r\n',
#  'but, alas! the little door was shut again, and the little golden key was\r\n',
#  'lying on the glass table as before, \xe2\x80\x98and things are worse than ever,\xe2\x80\x99\r\n',
#  'thought the poor child, \xe2\x80\x98for I never was so small as this before, never!\r\n',
#  'And I declare it\xe2\x80\x99s too bad, that it is!\xe2\x80\x99\r\n',
#  '\r\n',
#  'As she said these words her foot slipped, and in another moment, splash!\r\n',
#  'she was up to her chin in salt water. Her first idea was that she\r\n',
#  'had somehow fallen into the sea, \xe2\x80\x98and in that case I can go back by\r\n',
#  'railway,\xe2\x80\x99 she said to herself. (Alice had been to the seaside once in\r\n',
#  'her life, and had come to the general conclusion, that wherever you go\r\n',
#  'to on the English coast you find a number of bathing machines in the\r\n',
#  'sea, some children digging in the sand with wooden spades, then a row\r\n',
#  'of lodging houses, and behind them a railway station.) However, she soon\r\n',
#  'made out that she was in the pool of tears which she had wept when she\r\n',
#  'was nine feet high.\r\n',
#  '\r\n',
#  '\xe2\x80\x98I wish I hadn\xe2\x80\x99t cried so much!\xe2\x80\x99 said Alice, as she swam about, trying\r\n',
#  'to find her way out. \xe2\x80\x98I shall be punished for it now, I suppose, by\r\n',
#  'being drowned in my own tears! That WILL be a queer thing, to be sure!\r\n',
#  'However, everything is queer to-day.\xe2\x80\x99\r\n',
#  '\r\n',
#  'Just then she heard something splashing about in the pool a little way\r\n',
#  'off, and she swam nearer to make out what it was: at first she thought\r\n',
#  'it must be a walrus or hippopotamus, but then she remembered how small\r\n',
#  'she was now, and she soon made out that it was only a mouse that had\r\n',
#  'slipped in like herself.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Would it be of any use, now,\xe2\x80\x99 thought Alice, \xe2\x80\x98to speak to this mouse?\r\n',
#  'Everything is so out-of-the-way down here, that I should think very\r\n',
#  'likely it can talk: at any rate, there\xe2\x80\x99s no harm in trying.\xe2\x80\x99 So she\r\n',
#  'began: \xe2\x80\x98O Mouse, do you know the way out of this pool? I am very tired\r\n',
#  'of swimming about here, O Mouse!\xe2\x80\x99 (Alice thought this must be the right\r\n',
#  'way of speaking to a mouse: she had never done such a thing before, but\r\n',
#  'she remembered having seen in her brother\xe2\x80\x99s Latin Grammar, \xe2\x80\x98A mouse--of\r\n',
#  'a mouse--to a mouse--a mouse--O mouse!\xe2\x80\x99) The Mouse looked at her rather\r\n',
#  'inquisitively, and seemed to her to wink with one of its little eyes,\r\n',
#  'but it said nothing.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Perhaps it doesn\xe2\x80\x99t understand English,\xe2\x80\x99 thought Alice; \xe2\x80\x98I daresay it\xe2\x80\x99s\r\n',
#  'a French mouse, come over with William the Conqueror.\xe2\x80\x99 (For, with all\r\n',
#  'her knowledge of history, Alice had no very clear notion how long ago\r\n',
#  'anything had happened.) So she began again: \xe2\x80\x98Ou est ma chatte?\xe2\x80\x99 which\r\n',
#  'was the first sentence in her French lesson-book. The Mouse gave a\r\n',
#  'sudden leap out of the water, and seemed to quiver all over with fright.\r\n',
#  '\xe2\x80\x98Oh, I beg your pardon!\xe2\x80\x99 cried Alice hastily, afraid that she had hurt\r\n',
#  'the poor animal\xe2\x80\x99s feelings. \xe2\x80\x98I quite forgot you didn\xe2\x80\x99t like cats.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Not like cats!\xe2\x80\x99 cried the Mouse, in a shrill, passionate voice. \xe2\x80\x98Would\r\n',
#  'YOU like cats if you were me?\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Well, perhaps not,\xe2\x80\x99 said Alice in a soothing tone: \xe2\x80\x98don\xe2\x80\x99t be angry\r\n',
#  'about it. And yet I wish I could show you our cat Dinah: I think you\xe2\x80\x99d\r\n',
#  'take a fancy to cats if you could only see her. She is such a dear quiet\r\n',
#  'thing,\xe2\x80\x99 Alice went on, half to herself, as she swam lazily about in the\r\n',
#  'pool, \xe2\x80\x98and she sits purring so nicely by the fire, licking her paws and\r\n',
#  'washing her face--and she is such a nice soft thing to nurse--and she\xe2\x80\x99s\r\n',
#  'such a capital one for catching mice--oh, I beg your pardon!\xe2\x80\x99 cried\r\n',
#  'Alice again, for this time the Mouse was bristling all over, and she\r\n',
#  'felt certain it must be really offended. \xe2\x80\x98We won\xe2\x80\x99t talk about her any\r\n',
#  'more if you\xe2\x80\x99d rather not.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98We indeed!\xe2\x80\x99 cried the Mouse, who was trembling down to the end of his\r\n',
#  'tail. \xe2\x80\x98As if I would talk on such a subject! Our family always HATED\r\n',
#  'cats: nasty, low, vulgar things! Don\xe2\x80\x99t let me hear the name again!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I won\xe2\x80\x99t indeed!\xe2\x80\x99 said Alice, in a great hurry to change the subject of\r\n',
#  'conversation. \xe2\x80\x98Are you--are you fond--of--of dogs?\xe2\x80\x99 The Mouse did not\r\n',
#  'answer, so Alice went on eagerly: \xe2\x80\x98There is such a nice little dog near\r\n',
#  'our house I should like to show you! A little bright-eyed terrier, you\r\n',
#  'know, with oh, such long curly brown hair! And it\xe2\x80\x99ll fetch things when\r\n',
#  'you throw them, and it\xe2\x80\x99ll sit up and beg for its dinner, and all sorts\r\n',
#  'of things--I can\xe2\x80\x99t remember half of them--and it belongs to a farmer,\r\n',
#  'you know, and he says it\xe2\x80\x99s so useful, it\xe2\x80\x99s worth a hundred pounds! He\r\n',
#  'says it kills all the rats and--oh dear!\xe2\x80\x99 cried Alice in a sorrowful\r\n',
#  'tone, \xe2\x80\x98I\xe2\x80\x99m afraid I\xe2\x80\x99ve offended it again!\xe2\x80\x99 For the Mouse was swimming\r\n',
#  'away from her as hard as it could go, and making quite a commotion in\r\n',
#  'the pool as it went.\r\n',
#  '\r\n',
#  'So she called softly after it, \xe2\x80\x98Mouse dear! Do come back again, and we\r\n',
#  'won\xe2\x80\x99t talk about cats or dogs either, if you don\xe2\x80\x99t like them!\xe2\x80\x99 When the\r\n',
#  'Mouse heard this, it turned round and swam slowly back to her: its\r\n',
#  'face was quite pale (with passion, Alice thought), and it said in a low\r\n',
#  'trembling voice, \xe2\x80\x98Let us get to the shore, and then I\xe2\x80\x99ll tell you my\r\n',
#  'history, and you\xe2\x80\x99ll understand why it is I hate cats and dogs.\xe2\x80\x99\r\n',
#  '\r\n',
#  'It was high time to go, for the pool was getting quite crowded with the\r\n',
#  'birds and animals that had fallen into it: there were a Duck and a Dodo,\r\n',
#  'a Lory and an Eaglet, and several other curious creatures. Alice led the\r\n',
#  'way, and the whole party swam to the shore.\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  'CHAPTER III. A Caucus-Race and a Long Tale\r\n',
#  '\r\n',
#  'They were indeed a queer-looking party that assembled on the bank--the\r\n',
#  'birds with draggled feathers, the animals with their fur clinging close\r\n',
#  'to them, and all dripping wet, cross, and uncomfortable.\r\n',
#  '\r\n',
#  'The first question of course was, how to get dry again: they had a\r\n',
#  'consultation about this, and after a few minutes it seemed quite natural\r\n',
#  'to Alice to find herself talking familiarly with them, as if she had\r\n',
#  'known them all her life. Indeed, she had quite a long argument with the\r\n',
#  'Lory, who at last turned sulky, and would only say, \xe2\x80\x98I am older than\r\n',
#  'you, and must know better\xe2\x80\x99; and this Alice would not allow without\r\n',
#  'knowing how old it was, and, as the Lory positively refused to tell its\r\n',
#  'age, there was no more to be said.\r\n',
#  '\r\n',
#  'At last the Mouse, who seemed to be a person of authority among them,\r\n',
#  'called out, \xe2\x80\x98Sit down, all of you, and listen to me! I\xe2\x80\x99LL soon make you\r\n',
#  'dry enough!\xe2\x80\x99 They all sat down at once, in a large ring, with the Mouse\r\n',
#  'in the middle. Alice kept her eyes anxiously fixed on it, for she felt\r\n',
#  'sure she would catch a bad cold if she did not get dry very soon.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Ahem!\xe2\x80\x99 said the Mouse with an important air, \xe2\x80\x98are you all ready? This\r\n',
#  'is the driest thing I know. Silence all round, if you please! \xe2\x80\x9cWilliam\r\n',
#  'the Conqueror, whose cause was favoured by the pope, was soon submitted\r\n',
#  'to by the English, who wanted leaders, and had been of late much\r\n',
#  'accustomed to usurpation and conquest. Edwin and Morcar, the earls of\r\n',
#  'Mercia and Northumbria--\xe2\x80\x9c\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Ugh!\xe2\x80\x99 said the Lory, with a shiver.\r\n',
#  '\r\n',
#  '\xe2\x80\x98I beg your pardon!\xe2\x80\x99 said the Mouse, frowning, but very politely: \xe2\x80\x98Did\r\n',
#  'you speak?\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Not I!\xe2\x80\x99 said the Lory hastily.\r\n',
#  '\r\n',
#  '\xe2\x80\x98I thought you did,\xe2\x80\x99 said the Mouse. \xe2\x80\x98--I proceed. \xe2\x80\x9cEdwin and Morcar,\r\n',
#  'the earls of Mercia and Northumbria, declared for him: and even Stigand,\r\n',
#  'the patriotic archbishop of Canterbury, found it advisable--\xe2\x80\x9c\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Found WHAT?\xe2\x80\x99 said the Duck.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Found IT,\xe2\x80\x99 the Mouse replied rather crossly: \xe2\x80\x98of course you know what\r\n',
#  '\xe2\x80\x9cit\xe2\x80\x9d means.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I know what \xe2\x80\x9cit\xe2\x80\x9d means well enough, when I find a thing,\xe2\x80\x99 said the\r\n',
#  'Duck: \xe2\x80\x98it\xe2\x80\x99s generally a frog or a worm. The question is, what did the\r\n',
#  'archbishop find?\xe2\x80\x99\r\n',
#  '\r\n',
#  'The Mouse did not notice this question, but hurriedly went on, \xe2\x80\x98\xe2\x80\x9c--found\r\n',
#  'it advisable to go with Edgar Atheling to meet William and offer him the\r\n',
#  'crown. William\xe2\x80\x99s conduct at first was moderate. But the insolence of his\r\n',
#  'Normans--\xe2\x80\x9d How are you getting on now, my dear?\xe2\x80\x99 it continued, turning\r\n',
#  'to Alice as it spoke.\r\n',
#  '\r\n',
#  '\xe2\x80\x98As wet as ever,\xe2\x80\x99 said Alice in a melancholy tone: \xe2\x80\x98it doesn\xe2\x80\x99t seem to\r\n',
#  'dry me at all.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98In that case,\xe2\x80\x99 said the Dodo solemnly, rising to its feet, \xe2\x80\x98I move\r\n',
#  'that the meeting adjourn, for the immediate adoption of more energetic\r\n',
#  'remedies--\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Speak English!\xe2\x80\x99 said the Eaglet. \xe2\x80\x98I don\xe2\x80\x99t know the meaning of half\r\n',
#  'those long words, and, what\xe2\x80\x99s more, I don\xe2\x80\x99t believe you do either!\xe2\x80\x99 And\r\n',
#  'the Eaglet bent down its head to hide a smile: some of the other birds\r\n',
#  'tittered audibly.\r\n',
#  '\r\n',
#  '\xe2\x80\x98What I was going to say,\xe2\x80\x99 said the Dodo in an offended tone, \xe2\x80\x98was, that\r\n',
#  'the best thing to get us dry would be a Caucus-race.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98What IS a Caucus-race?\xe2\x80\x99 said Alice; not that she wanted much to know,\r\n',
#  'but the Dodo had paused as if it thought that SOMEBODY ought to speak,\r\n',
#  'and no one else seemed inclined to say anything.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Why,\xe2\x80\x99 said the Dodo, \xe2\x80\x98the best way to explain it is to do it.\xe2\x80\x99 (And, as\r\n',
#  'you might like to try the thing yourself, some winter day, I will tell\r\n',
#  'you how the Dodo managed it.)\r\n',
#  '\r\n',
#  'First it marked out a race-course, in a sort of circle, [\xe2\x80\x98the exact\r\n',
#  'shape doesn\xe2\x80\x99t matter,\xe2\x80\x99 it said,) and then all the party were placed\r\n',
#  'along the course, here and there. There was no \xe2\x80\x98One, two, three, and\r\n',
#  'away,\xe2\x80\x99 but they began running when they liked, and left off when they\r\n',
#  'liked, so that it was not easy to know when the race was over. However,\r\n',
#  'when they had been running half an hour or so, and were quite dry again,\r\n',
#  'the Dodo suddenly called out \xe2\x80\x98The race is over!\xe2\x80\x99 and they all crowded\r\n',
#  'round it, panting, and asking, \xe2\x80\x98But who has won?\xe2\x80\x99\r\n',
#  '\r\n',
#  'This question the Dodo could not answer without a great deal of thought,\r\n',
#  'and it sat for a long time with one finger pressed upon its forehead\r\n',
#  '(the position in which you usually see Shakespeare, in the pictures\r\n',
#  'of him), while the rest waited in silence. At last the Dodo said,\r\n',
#  '\xe2\x80\x98EVERYBODY has won, and all must have prizes.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98But who is to give the prizes?\xe2\x80\x99 quite a chorus of voices asked.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Why, SHE, of course,\xe2\x80\x99 said the Dodo, pointing to Alice with one finger;\r\n',
#  'and the whole party at once crowded round her, calling out in a confused\r\n',
#  'way, \xe2\x80\x98Prizes! Prizes!\xe2\x80\x99\r\n',
#  '\r\n',
#  'Alice had no idea what to do, and in despair she put her hand in her\r\n',
#  'pocket, and pulled out a box of comfits, (luckily the salt water had\r\n',
#  'not got into it), and handed them round as prizes. There was exactly one\r\n',
#  'a-piece all round.\r\n',
#  '\r\n',
#  '\xe2\x80\x98But she must have a prize herself, you know,\xe2\x80\x99 said the Mouse.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Of course,\xe2\x80\x99 the Dodo replied very gravely. \xe2\x80\x98What else have you got in\r\n',
#  'your pocket?\xe2\x80\x99 he went on, turning to Alice.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Only a thimble,\xe2\x80\x99 said Alice sadly.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Hand it over here,\xe2\x80\x99 said the Dodo.\r\n',
#  '\r\n',
#  'Then they all crowded round her once more, while the Dodo solemnly\r\n',
#  'presented the thimble, saying \xe2\x80\x98We beg your acceptance of this elegant\r\n',
#  'thimble\xe2\x80\x99; and, when it had finished this short speech, they all cheered.\r\n',
#  '\r\n',
#  'Alice thought the whole thing very absurd, but they all looked so grave\r\n',
#  'that she did not dare to laugh; and, as she could not think of anything\r\n',
#  'to say, she simply bowed, and took the thimble, looking as solemn as she\r\n',
#  'could.\r\n',
#  '\r\n',
#  'The next thing was to eat the comfits: this caused some noise and\r\n',
#  'confusion, as the large birds complained that they could not taste\r\n',
#  'theirs, and the small ones choked and had to be patted on the back.\r\n',
#  'However, it was over at last, and they sat down again in a ring, and\r\n',
#  'begged the Mouse to tell them something more.\r\n',
#  '\r\n',
#  '\xe2\x80\x98You promised to tell me your history, you know,\xe2\x80\x99 said Alice, \xe2\x80\x98and why\r\n',
#  'it is you hate--C and D,\xe2\x80\x99 she added in a whisper, half afraid that it\r\n',
#  'would be offended again.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Mine is a long and a sad tale!\xe2\x80\x99 said the Mouse, turning to Alice, and\r\n',
#  'sighing.\r\n',
#  '\r\n',
#  '\xe2\x80\x98It IS a long tail, certainly,\xe2\x80\x99 said Alice, looking down with wonder at\r\n',
#  'the Mouse\xe2\x80\x99s tail; \xe2\x80\x98but why do you call it sad?\xe2\x80\x99 And she kept on puzzling\r\n',
#  'about it while the Mouse was speaking, so that her idea of the tale was\r\n',
#  'something like this:--\r\n',
#  '\r\n',
#  '         \xe2\x80\x98Fury said to a\r\n',
#  '         mouse, That he\r\n',
#  '        met in the\r\n',
#  '       house,\r\n',
#  '     \xe2\x80\x9cLet us\r\n',
#  '      both go to\r\n',
#  '       law: I will\r\n',
#  '        prosecute\r\n',
#  '         YOU.--Come,\r\n',
#  '           I\xe2\x80\x99ll take no\r\n',
#  '           denial; We\r\n',
#  '          must have a\r\n',
#  '        trial: For\r\n',
#  '      really this\r\n',
#  '     morning I\xe2\x80\x99ve\r\n',
#  '    nothing\r\n',
#  '    to do.\xe2\x80\x9d\r\n',
#  '      Said the\r\n',
#  '      mouse to the\r\n',
#  '       cur, \xe2\x80\x9cSuch\r\n',
#  '        a trial,\r\n',
#  '         dear Sir,\r\n',
#  '            With\r\n',
#  '          no jury\r\n',
#  '        or judge,\r\n',
#  '       would be\r\n',
#  '      wasting\r\n',
#  '      our\r\n',
#  '      breath.\xe2\x80\x9d\r\n',
#  '        \xe2\x80\x9cI\xe2\x80\x99ll be\r\n',
#  '        judge, I\xe2\x80\x99ll\r\n',
#  '         be jury,\xe2\x80\x9d\r\n',
#  '             Said\r\n',
#  '         cunning\r\n',
#  '          old Fury:\r\n',
#  '          \xe2\x80\x9cI\xe2\x80\x99ll\r\n',
#  '          try the\r\n',
#  '            whole\r\n',
#  '            cause,\r\n',
#  '              and\r\n',
#  '           condemn\r\n',
#  '           you\r\n',
#  '          to\r\n',
#  '           death.\xe2\x80\x9d\xe2\x80\x99\r\n',
#  '\r\n',
#  '\r\n',
#  '\xe2\x80\x98You are not attending!\xe2\x80\x99 said the Mouse to Alice severely. \xe2\x80\x98What are you\r\n',
#  'thinking of?\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I beg your pardon,\xe2\x80\x99 said Alice very humbly: \xe2\x80\x98you had got to the fifth\r\n',
#  'bend, I think?\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I had NOT!\xe2\x80\x99 cried the Mouse, sharply and very angrily.\r\n',
#  '\r\n',
#  '\xe2\x80\x98A knot!\xe2\x80\x99 said Alice, always ready to make herself useful, and looking\r\n',
#  'anxiously about her. \xe2\x80\x98Oh, do let me help to undo it!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I shall do nothing of the sort,\xe2\x80\x99 said the Mouse, getting up and walking\r\n',
#  'away. \xe2\x80\x98You insult me by talking such nonsense!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I didn\xe2\x80\x99t mean it!\xe2\x80\x99 pleaded poor Alice. \xe2\x80\x98But you\xe2\x80\x99re so easily offended,\r\n',
#  'you know!\xe2\x80\x99\r\n',
#  '\r\n',
#  'The Mouse only growled in reply.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Please come back and finish your story!\xe2\x80\x99 Alice called after it; and the\r\n',
#  'others all joined in chorus, \xe2\x80\x98Yes, please do!\xe2\x80\x99 but the Mouse only shook\r\n',
#  'its head impatiently, and walked a little quicker.\r\n',
#  '\r\n',
#  '\xe2\x80\x98What a pity it wouldn\xe2\x80\x99t stay!\xe2\x80\x99 sighed the Lory, as soon as it was quite\r\n',
#  'out of sight; and an old Crab took the opportunity of saying to her\r\n',
#  'daughter \xe2\x80\x98Ah, my dear! Let this be a lesson to you never to lose\r\n',
#  'YOUR temper!\xe2\x80\x99 \xe2\x80\x98Hold your tongue, Ma!\xe2\x80\x99 said the young Crab, a little\r\n',
#  'snappishly. \xe2\x80\x98You\xe2\x80\x99re enough to try the patience of an oyster!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I wish I had our Dinah here, I know I do!\xe2\x80\x99 said Alice aloud, addressing\r\n',
#  'nobody in particular. \xe2\x80\x98She\xe2\x80\x99d soon fetch it back!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98And who is Dinah, if I might venture to ask the question?\xe2\x80\x99 said the\r\n',
#  'Lory.\r\n',
#  '\r\n',
#  'Alice replied eagerly, for she was always ready to talk about her pet:\r\n',
#  '\xe2\x80\x98Dinah\xe2\x80\x99s our cat. And she\xe2\x80\x99s such a capital one for catching mice you\r\n',
#  'can\xe2\x80\x99t think! And oh, I wish you could see her after the birds! Why,\r\n',
#  'she\xe2\x80\x99ll eat a little bird as soon as look at it!\xe2\x80\x99\r\n',
#  '\r\n',
#  'This speech caused a remarkable sensation among the party. Some of the\r\n',
#  'birds hurried off at once: one old Magpie began wrapping itself up very\r\n',
#  'carefully, remarking, \xe2\x80\x98I really must be getting home; the night-air\r\n',
#  'doesn\xe2\x80\x99t suit my throat!\xe2\x80\x99 and a Canary called out in a trembling voice to\r\n',
#  'its children, \xe2\x80\x98Come away, my dears! It\xe2\x80\x99s high time you were all in bed!\xe2\x80\x99\r\n',
#  'On various pretexts they all moved off, and Alice was soon left alone.\r\n',
#  '\r\n',
#  '\xe2\x80\x98I wish I hadn\xe2\x80\x99t mentioned Dinah!\xe2\x80\x99 she said to herself in a melancholy\r\n',
#  'tone. \xe2\x80\x98Nobody seems to like her, down here, and I\xe2\x80\x99m sure she\xe2\x80\x99s the best\r\n',
#  'cat in the world! Oh, my dear Dinah! I wonder if I shall ever see you\r\n',
#  'any more!\xe2\x80\x99 And here poor Alice began to cry again, for she felt very\r\n',
#  'lonely and low-spirited. In a little while, however, she again heard\r\n',
#  'a little pattering of footsteps in the distance, and she looked up\r\n',
#  'eagerly, half hoping that the Mouse had changed his mind, and was coming\r\n',
#  'back to finish his story.\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  'CHAPTER IV. The Rabbit Sends in a Little Bill\r\n',
#  '\r\n',
#  'It was the White Rabbit, trotting slowly back again, and looking\r\n',
#  'anxiously about as it went, as if it had lost something; and she heard\r\n',
#  'it muttering to itself \xe2\x80\x98The Duchess! The Duchess! Oh my dear paws! Oh\r\n',
#  'my fur and whiskers! She\xe2\x80\x99ll get me executed, as sure as ferrets are\r\n',
#  'ferrets! Where CAN I have dropped them, I wonder?\xe2\x80\x99 Alice guessed in a\r\n',
#  'moment that it was looking for the fan and the pair of white kid gloves,\r\n',
#  'and she very good-naturedly began hunting about for them, but they were\r\n',
#  'nowhere to be seen--everything seemed to have changed since her swim in\r\n',
#  'the pool, and the great hall, with the glass table and the little door,\r\n',
#  'had vanished completely.\r\n',
#  '\r\n',
#  'Very soon the Rabbit noticed Alice, as she went hunting about, and\r\n',
#  'called out to her in an angry tone, \xe2\x80\x98Why, Mary Ann, what ARE you doing\r\n',
#  'out here? Run home this moment, and fetch me a pair of gloves and a fan!\r\n',
#  'Quick, now!\xe2\x80\x99 And Alice was so much frightened that she ran off at once\r\n',
#  'in the direction it pointed to, without trying to explain the mistake it\r\n',
#  'had made.\r\n',
#  '\r\n',
#  '\xe2\x80\x98He took me for his housemaid,\xe2\x80\x99 she said to herself as she ran. \xe2\x80\x98How\r\n',
#  'surprised he\xe2\x80\x99ll be when he finds out who I am! But I\xe2\x80\x99d better take him\r\n',
#  'his fan and gloves--that is, if I can find them.\xe2\x80\x99 As she said this, she\r\n',
#  'came upon a neat little house, on the door of which was a bright brass\r\n',
#  'plate with the name \xe2\x80\x98W. RABBIT\xe2\x80\x99 engraved upon it. She went in without\r\n',
#  'knocking, and hurried upstairs, in great fear lest she should meet the\r\n',
#  'real Mary Ann, and be turned out of the house before she had found the\r\n',
#  'fan and gloves.\r\n',
#  '\r\n',
#  '\xe2\x80\x98How queer it seems,\xe2\x80\x99 Alice said to herself, \xe2\x80\x98to be going messages for\r\n',
#  'a rabbit! I suppose Dinah\xe2\x80\x99ll be sending me on messages next!\xe2\x80\x99 And she\r\n',
#  'began fancying the sort of thing that would happen: \xe2\x80\x98\xe2\x80\x9cMiss Alice! Come\r\n',
#  'here directly, and get ready for your walk!\xe2\x80\x9d \xe2\x80\x9cComing in a minute,\r\n',
#  'nurse! But I\xe2\x80\x99ve got to see that the mouse doesn\xe2\x80\x99t get out.\xe2\x80\x9d Only I don\xe2\x80\x99t\r\n',
#  'think,\xe2\x80\x99 Alice went on, \xe2\x80\x98that they\xe2\x80\x99d let Dinah stop in the house if it\r\n',
#  'began ordering people about like that!\xe2\x80\x99\r\n',
#  '\r\n',
#  'By this time she had found her way into a tidy little room with a table\r\n',
#  'in the window, and on it (as she had hoped) a fan and two or three pairs\r\n',
#  'of tiny white kid gloves: she took up the fan and a pair of the gloves,\r\n',
#  'and was just going to leave the room, when her eye fell upon a little\r\n',
#  'bottle that stood near the looking-glass. There was no label this time\r\n',
#  'with the words \xe2\x80\x98DRINK ME,\xe2\x80\x99 but nevertheless she uncorked it and put it\r\n',
#  'to her lips. \xe2\x80\x98I know SOMETHING interesting is sure to happen,\xe2\x80\x99 she said\r\n',
#  'to herself, \xe2\x80\x98whenever I eat or drink anything; so I\xe2\x80\x99ll just see what\r\n',
#  'this bottle does. I do hope it\xe2\x80\x99ll make me grow large again, for really\r\n',
#  'I\xe2\x80\x99m quite tired of being such a tiny little thing!\xe2\x80\x99\r\n',
#  '\r\n',
#  'It did so indeed, and much sooner than she had expected: before she had\r\n',
#  'drunk half the bottle, she found her head pressing against the ceiling,\r\n',
#  'and had to stoop to save her neck from being broken. She hastily put\r\n',
#  'down the bottle, saying to herself \xe2\x80\x98That\xe2\x80\x99s quite enough--I hope I shan\xe2\x80\x99t\r\n',
#  'grow any more--As it is, I can\xe2\x80\x99t get out at the door--I do wish I hadn\xe2\x80\x99t\r\n',
#  'drunk quite so much!\xe2\x80\x99\r\n',
#  '\r\n',
#  'Alas! it was too late to wish that! She went on growing, and growing,\r\n',
#  'and very soon had to kneel down on the floor: in another minute there\r\n',
#  'was not even room for this, and she tried the effect of lying down with\r\n',
#  'one elbow against the door, and the other arm curled round her head.\r\n',
#  'Still she went on growing, and, as a last resource, she put one arm out\r\n',
# ...
#  'and she grew no larger: still it was very uncomfortable, and, as there\r\n',
#  'seemed to be no sort of chance of her ever getting out of the room\r\n',
#  'again, no wonder she felt unhappy.\r\n',
#  '\r\n',
#  '\xe2\x80\x98It was much pleasanter at home,\xe2\x80\x99 thought poor Alice, \xe2\x80\x98when one wasn\xe2\x80\x99t\r\n',
#  'always growing larger and smaller, and being ordered about by mice and\r\n',
#  'rabbits. I almost wish I hadn\xe2\x80\x99t gone down that rabbit-hole--and yet--and\r\n',
#  'yet--it\xe2\x80\x99s rather curious, you know, this sort of life! I do wonder what\r\n',
#  'CAN have happened to me! When I used to read fairy-tales, I fancied that\r\n',
#  'kind of thing never happened, and now here I am in the middle of one!\r\n',
#  'There ought to be a book written about me, that there ought! And when I\r\n',
#  'grow up, I\xe2\x80\x99ll write one--but I\xe2\x80\x99m grown up now,\xe2\x80\x99 she added in a sorrowful\r\n',
#  'tone; \xe2\x80\x98at least there\xe2\x80\x99s no room to grow up any more HERE.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98But then,\xe2\x80\x99 thought Alice, \xe2\x80\x98shall I NEVER get any older than I am\r\n',
#  'now? That\xe2\x80\x99ll be a comfort, one way--never to be an old woman--but\r\n',
#  'then--always to have lessons to learn! Oh, I shouldn\xe2\x80\x99t like THAT!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Oh, you foolish Alice!\xe2\x80\x99 she answered herself. \xe2\x80\x98How can you learn\r\n',
#  'lessons in here? Why, there\xe2\x80\x99s hardly room for YOU, and no room at all\r\n',
#  'for any lesson-books!\xe2\x80\x99\r\n',
#  '\r\n',
#  'And so she went on, taking first one side and then the other, and making\r\n',
#  'quite a conversation of it altogether; but after a few minutes she heard\r\n',
#  'a voice outside, and stopped to listen.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Mary Ann! Mary Ann!\xe2\x80\x99 said the voice. \xe2\x80\x98Fetch me my gloves this moment!\xe2\x80\x99\r\n',
#  'Then came a little pattering of feet on the stairs. Alice knew it was\r\n',
#  'the Rabbit coming to look for her, and she trembled till she shook the\r\n',
#  'house, quite forgetting that she was now about a thousand times as large\r\n',
#  'as the Rabbit, and had no reason to be afraid of it.\r\n',
#  '\r\n',
#  'Presently the Rabbit came up to the door, and tried to open it; but, as\r\n',
#  'the door opened inwards, and Alice\xe2\x80\x99s elbow was pressed hard against it,\r\n',
#  'that attempt proved a failure. Alice heard it say to itself \xe2\x80\x98Then I\xe2\x80\x99ll\r\n',
#  'go round and get in at the window.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98THAT you won\xe2\x80\x99t\xe2\x80\x99 thought Alice, and, after waiting till she fancied\r\n',
#  'she heard the Rabbit just under the window, she suddenly spread out her\r\n',
#  'hand, and made a snatch in the air. She did not get hold of anything,\r\n',
#  'but she heard a little shriek and a fall, and a crash of broken glass,\r\n',
#  'from which she concluded that it was just possible it had fallen into a\r\n',
#  'cucumber-frame, or something of the sort.\r\n',
#  '\r\n',
#  'Next came an angry voice--the Rabbit\xe2\x80\x99s--\xe2\x80\x98Pat! Pat! Where are you?\xe2\x80\x99 And\r\n',
#  'then a voice she had never heard before, \xe2\x80\x98Sure then I\xe2\x80\x99m here! Digging\r\n',
#  'for apples, yer honour!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Digging for apples, indeed!\xe2\x80\x99 said the Rabbit angrily. \xe2\x80\x98Here! Come and\r\n',
#  'help me out of THIS!\xe2\x80\x99 (Sounds of more broken glass.)\r\n',
#  '\r\n',
#  '\xe2\x80\x98Now tell me, Pat, what\xe2\x80\x99s that in the window?\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Sure, it\xe2\x80\x99s an arm, yer honour!\xe2\x80\x99 (He pronounced it \xe2\x80\x98arrum.\xe2\x80\x99)\r\n',
#  '\r\n',
#  '\xe2\x80\x98An arm, you goose! Who ever saw one that size? Why, it fills the whole\r\n',
#  'window!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Sure, it does, yer honour: but it\xe2\x80\x99s an arm for all that.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Well, it\xe2\x80\x99s got no business there, at any rate: go and take it away!\xe2\x80\x99\r\n',
#  '\r\n',
#  'There was a long silence after this, and Alice could only hear whispers\r\n',
#  'now and then; such as, \xe2\x80\x98Sure, I don\xe2\x80\x99t like it, yer honour, at all, at\r\n',
#  'all!\xe2\x80\x99 \xe2\x80\x98Do as I tell you, you coward!\xe2\x80\x99 and at last she spread out her\r\n',
#  'hand again, and made another snatch in the air. This time there were\r\n',
#  'TWO little shrieks, and more sounds of broken glass. \xe2\x80\x98What a number of\r\n',
#  'cucumber-frames there must be!\xe2\x80\x99 thought Alice. \xe2\x80\x98I wonder what they\xe2\x80\x99ll do\r\n',
#  'next! As for pulling me out of the window, I only wish they COULD! I\xe2\x80\x99m\r\n',
#  'sure I don\xe2\x80\x99t want to stay in here any longer!\xe2\x80\x99\r\n',
#  '\r\n',
#  'She waited for some time without hearing anything more: at last came a\r\n',
#  'rumbling of little cartwheels, and the sound of a good many voices\r\n',
#  'all talking together: she made out the words: \xe2\x80\x98Where\xe2\x80\x99s the other\r\n',
#  'ladder?--Why, I hadn\xe2\x80\x99t to bring but one; Bill\xe2\x80\x99s got the other--Bill!\r\n',
#  'fetch it here, lad!--Here, put \xe2\x80\x98em up at this corner--No, tie \xe2\x80\x98em\r\n',
#  'together first--they don\xe2\x80\x99t reach half high enough yet--Oh! they\xe2\x80\x99ll\r\n',
#  'do well enough; don\xe2\x80\x99t be particular--Here, Bill! catch hold of this\r\n',
#  'rope--Will the roof bear?--Mind that loose slate--Oh, it\xe2\x80\x99s coming\r\n',
#  'down! Heads below!\xe2\x80\x99 (a loud crash)--\xe2\x80\x98Now, who did that?--It was Bill, I\r\n',
#  'fancy--Who\xe2\x80\x99s to go down the chimney?--Nay, I shan\xe2\x80\x99t! YOU do it!--That I\r\n',
#  'won\xe2\x80\x99t, then!--Bill\xe2\x80\x99s to go down--Here, Bill! the master says you\xe2\x80\x99re to\r\n',
#  'go down the chimney!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Oh! So Bill\xe2\x80\x99s got to come down the chimney, has he?\xe2\x80\x99 said Alice to\r\n',
#  'herself. \xe2\x80\x98Shy, they seem to put everything upon Bill! I wouldn\xe2\x80\x99t be in\r\n',
#  'Bill\xe2\x80\x99s place for a good deal: this fireplace is narrow, to be sure; but\r\n',
#  'I THINK I can kick a little!\xe2\x80\x99\r\n',
#  '\r\n',
#  'She drew her foot as far down the chimney as she could, and waited\r\n',
#  'till she heard a little animal (she couldn\xe2\x80\x99t guess of what sort it was)\r\n',
#  'scratching and scrambling about in the chimney close above her: then,\r\n',
#  'saying to herself \xe2\x80\x98This is Bill,\xe2\x80\x99 she gave one sharp kick, and waited to\r\n',
#  'see what would happen next.\r\n',
#  '\r\n',
#  'The first thing she heard was a general chorus of \xe2\x80\x98There goes Bill!\xe2\x80\x99\r\n',
#  'then the Rabbit\xe2\x80\x99s voice along--\xe2\x80\x98Catch him, you by the hedge!\xe2\x80\x99 then\r\n',
#  'silence, and then another confusion of voices--\xe2\x80\x98Hold up his head--Brandy\r\n',
#  'now--Don\xe2\x80\x99t choke him--How was it, old fellow? What happened to you? Tell\r\n',
#  'us all about it!\xe2\x80\x99\r\n',
#  '\r\n',
#  'Last came a little feeble, squeaking voice, [\xe2\x80\x98That\xe2\x80\x99s Bill,\xe2\x80\x99 thought\r\n',
#  'Alice,) \xe2\x80\x98Well, I hardly know--No more, thank ye; I\xe2\x80\x99m better now--but I\xe2\x80\x99m\r\n',
#  'a deal too flustered to tell you--all I know is, something comes at me\r\n',
#  'like a Jack-in-the-box, and up I goes like a sky-rocket!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98So you did, old fellow!\xe2\x80\x99 said the others.\r\n',
#  '\r\n',
#  '\xe2\x80\x98We must burn the house down!\xe2\x80\x99 said the Rabbit\xe2\x80\x99s voice; and Alice called\r\n',
#  'out as loud as she could, \xe2\x80\x98If you do. I\xe2\x80\x99ll set Dinah at you!\xe2\x80\x99\r\n',
#  '\r\n',
#  'There was a dead silence instantly, and Alice thought to herself, \xe2\x80\x98I\r\n',
#  'wonder what they WILL do next! If they had any sense, they\xe2\x80\x99d take the\r\n',
#  'roof off.\xe2\x80\x99 After a minute or two, they began moving about again, and\r\n',
#  'Alice heard the Rabbit say, \xe2\x80\x98A barrowful will do, to begin with.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98A barrowful of WHAT?\xe2\x80\x99 thought Alice; but she had not long to doubt,\r\n',
#  'for the next moment a shower of little pebbles came rattling in at the\r\n',
#  'window, and some of them hit her in the face. \xe2\x80\x98I\xe2\x80\x99ll put a stop to this,\xe2\x80\x99\r\n',
#  'she said to herself, and shouted out, \xe2\x80\x98You\xe2\x80\x99d better not do that again!\xe2\x80\x99\r\n',
#  'which produced another dead silence.\r\n',
#  '\r\n',
#  'Alice noticed with some surprise that the pebbles were all turning into\r\n',
#  'little cakes as they lay on the floor, and a bright idea came into her\r\n',
#  'head. \xe2\x80\x98If I eat one of these cakes,\xe2\x80\x99 she thought, \xe2\x80\x98it\xe2\x80\x99s sure to make\r\n',
#  'SOME change in my size; and as it can\xe2\x80\x99t possibly make me larger, it must\r\n',
#  'make me smaller, I suppose.\xe2\x80\x99\r\n',
#  '\r\n',
#  'So she swallowed one of the cakes, and was delighted to find that she\r\n',
#  'began shrinking directly. As soon as she was small enough to get through\r\n',
#  'the door, she ran out of the house, and found quite a crowd of little\r\n',
#  'animals and birds waiting outside. The poor little Lizard, Bill, was\r\n',
#  'in the middle, being held up by two guinea-pigs, who were giving it\r\n',
#  'something out of a bottle. They all made a rush at Alice the moment she\r\n',
#  'appeared; but she ran off as hard as she could, and soon found herself\r\n',
#  'safe in a thick wood.\r\n',
#  '\r\n',
#  '\xe2\x80\x98The first thing I\xe2\x80\x99ve got to do,\xe2\x80\x99 said Alice to herself, as she wandered\r\n',
#  'about in the wood, \xe2\x80\x98is to grow to my right size again; and the second\r\n',
#  'thing is to find my way into that lovely garden. I think that will be\r\n',
#  'the best plan.\xe2\x80\x99\r\n',
#  '\r\n',
#  'It sounded an excellent plan, no doubt, and very neatly and simply\r\n',
#  'arranged; the only difficulty was, that she had not the smallest idea\r\n',
#  'how to set about it; and while she was peering about anxiously among\r\n',
#  'the trees, a little sharp bark just over her head made her look up in a\r\n',
#  'great hurry.\r\n',
#  '\r\n',
#  'An enormous puppy was looking down at her with large round eyes, and\r\n',
#  'feebly stretching out one paw, trying to touch her. \xe2\x80\x98Poor little thing!\xe2\x80\x99\r\n',
#  'said Alice, in a coaxing tone, and she tried hard to whistle to it; but\r\n',
#  'she was terribly frightened all the time at the thought that it might be\r\n',
#  'hungry, in which case it would be very likely to eat her up in spite of\r\n',
#  'all her coaxing.\r\n',
#  '\r\n',
#  'Hardly knowing what she did, she picked up a little bit of stick, and\r\n',
#  'held it out to the puppy; whereupon the puppy jumped into the air off\r\n',
#  'all its feet at once, with a yelp of delight, and rushed at the stick,\r\n',
#  'and made believe to worry it; then Alice dodged behind a great thistle,\r\n',
#  'to keep herself from being run over; and the moment she appeared on the\r\n',
#  'other side, the puppy made another rush at the stick, and tumbled head\r\n',
#  'over heels in its hurry to get hold of it; then Alice, thinking it was\r\n',
#  'very like having a game of play with a cart-horse, and expecting every\r\n',
#  'moment to be trampled under its feet, ran round the thistle again; then\r\n',
#  'the puppy began a series of short charges at the stick, running a very\r\n',
#  'little way forwards each time and a long way back, and barking hoarsely\r\n',
#  'all the while, till at last it sat down a good way off, panting, with\r\n',
#  'its tongue hanging out of its mouth, and its great eyes half shut.\r\n',
#  '\r\n',
#  'This seemed to Alice a good opportunity for making her escape; so she\r\n',
#  'set off at once, and ran till she was quite tired and out of breath, and\r\n',
#  'till the puppy\xe2\x80\x99s bark sounded quite faint in the distance.\r\n',
#  '\r\n',
#  '\xe2\x80\x98And yet what a dear little puppy it was!\xe2\x80\x99 said Alice, as she leant\r\n',
#  'against a buttercup to rest herself, and fanned herself with one of the\r\n',
#  'leaves: \xe2\x80\x98I should have liked teaching it tricks very much, if--if I\xe2\x80\x99d\r\n',
#  'only been the right size to do it! Oh dear! I\xe2\x80\x99d nearly forgotten that\r\n',
#  'I\xe2\x80\x99ve got to grow up again! Let me see--how IS it to be managed? I\r\n',
#  'suppose I ought to eat or drink something or other; but the great\r\n',
#  'question is, what?\xe2\x80\x99\r\n',
#  '\r\n',
#  'The great question certainly was, what? Alice looked all round her at\r\n',
#  'the flowers and the blades of grass, but she did not see anything that\r\n',
#  'looked like the right thing to eat or drink under the circumstances.\r\n',
#  'There was a large mushroom growing near her, about the same height as\r\n',
#  'herself; and when she had looked under it, and on both sides of it, and\r\n',
#  'behind it, it occurred to her that she might as well look and see what\r\n',
#  'was on the top of it.\r\n',
#  '\r\n',
#  'She stretched herself up on tiptoe, and peeped over the edge of the\r\n',
#  'mushroom, and her eyes immediately met those of a large caterpillar,\r\n',
#  'that was sitting on the top with its arms folded, quietly smoking a long\r\n',
#  'hookah, and taking not the smallest notice of her or of anything else.\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  '\r\n',
#  'CHAPTER V. Advice from a Caterpillar\r\n',
#  '\r\n',
#  'The Caterpillar and Alice looked at each other for some time in silence:\r\n',
#  'at last the Caterpillar took the hookah out of its mouth, and addressed\r\n',
#  'her in a languid, sleepy voice.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Who are YOU?\xe2\x80\x99 said the Caterpillar.\r\n',
#  '\r\n',
#  'This was not an encouraging opening for a conversation. Alice replied,\r\n',
#  'rather shyly, \xe2\x80\x98I--I hardly know, sir, just at present--at least I know\r\n',
#  'who I WAS when I got up this morning, but I think I must have been\r\n',
#  'changed several times since then.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98What do you mean by that?\xe2\x80\x99 said the Caterpillar sternly. \xe2\x80\x98Explain\r\n',
#  'yourself!\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I can\xe2\x80\x99t explain MYSELF, I\xe2\x80\x99m afraid, sir\xe2\x80\x99 said Alice, \xe2\x80\x98because I\xe2\x80\x99m not\r\n',
#  'myself, you see.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98I don\xe2\x80\x99t see,\xe2\x80\x99 said the Caterpillar.\r\n',
#  '\r\n',
#  '\xe2\x80\x98I\xe2\x80\x99m afraid I can\xe2\x80\x99t put it more clearly,\xe2\x80\x99 Alice replied very politely,\r\n',
#  '\xe2\x80\x98for I can\xe2\x80\x99t understand it myself to begin with; and being so many\r\n',
#  'different sizes in a day is very confusing.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98It isn\xe2\x80\x99t,\xe2\x80\x99 said the Caterpillar.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Well, perhaps you haven\xe2\x80\x99t found it so yet,\xe2\x80\x99 said Alice; \xe2\x80\x98but when you\r\n',
#  'have to turn into a chrysalis--you will some day, you know--and then\r\n',
#  'after that into a butterfly, I should think you\xe2\x80\x99ll feel it a little\r\n',
#  'queer, won\xe2\x80\x99t you?\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98Not a bit,\xe2\x80\x99 said the Caterpillar.\r\n',
#  '\r\n',
#  '\xe2\x80\x98Well, perhaps your feelings may be different,\xe2\x80\x99 said Alice; \xe2\x80\x98all I know\r\n',
#  'is, it would feel very queer to ME.\xe2\x80\x99\r\n',
#  '\r\n',
#  '\xe2\x80\x98You!\xe2\x80\x99 said the Caterpillar contemptuously. \xe2\x80\x98Who are YOU?\xe2\x80\x99\r\n',
#  '\r\n',
#  'Which brought them back again to the beginning of the conversation.\r\n',
#  'Alice felt a little irritated at the Caterpillar\xe2\x80\x99s making such VERY\r\n',
#  'short remarks, and she drew herself up and said, very gravely, \xe2\x80\x98I think,\r\n',
#  ...]
